# %%
import numpy as np
import pandas as pd
import requests

# %%
response = requests.get(
    "https://api.collegefootballdata.com/games",
    params={"year": 2019, "seasonType": "both"}
)

data = pd.read_json(response.text)
data.head()
# Out:
#           id  season  week season_type                start_date  \
# 0  401110723    2019     1     regular  2019-08-24T23:00:00.000Z
# 1  401114164    2019     1     regular  2019-08-25T02:30:00.000Z
# 2  401119255    2019     1     regular  2019-08-29T23:00:00.000Z
# 3  401119254    2019     1     regular  2019-08-29T23:00:00.000Z
# 4  401117854    2019     1     regular  2019-08-29T23:00:00.000Z
#
#    neutral_site  conference_game  attendance  venue_id                  venue  \
# 0          True            False         NaN      4013  Camping World Stadium
# 1         False            False         NaN      3610          Aloha Stadium
# 2         False            False         NaN      3965             UB Stadium
# 3         False            False         NaN      3700     Doyt Perry Stadium
# 4         False            False         NaN      3854        Nippert Stadium
#
#        home_team    home_conference  home_points home_line_scores  \
# 0        Florida                SEC         24.0    [7, 0, 10, 7]
# 1        Hawai'i      Mountain West         45.0  [14, 14, 7, 10]
# 2        Buffalo       Mid-American         38.0   [21, 7, 10, 0]
# 3  Bowling Green       Mid-American         46.0   [13, 17, 7, 9]
# 4     Cincinnati  American Athletic         24.0     [7, 3, 7, 7]
#
#    home_post_win_prob      away_team away_conference  away_points  \
# 0            0.905953          Miami             ACC         20.0
# 1            0.688630        Arizona          Pac-12         38.0
# 2            0.999788  Robert Morris            None         10.0
# 3            0.999979   Morgan State            None          3.0
# 4            0.996829           UCLA          Pac-12         14.0
#
#   away_line_scores  away_post_win_prob
# 0    [3, 10, 0, 7]            0.094047
# 1   [0, 21, 14, 3]            0.311370
# 2     [7, 3, 0, 0]            0.000212
# 3     [0, 3, 0, 0]            0.000021
# 4     [0, 7, 7, 0]            0.003171

# %%
data = data[
    (data['home_points'] == data['home_points']) # filtering out future games
    & (data['away_points'] == data['away_points'])
    & (pd.notna(data['home_conference'])) # games with a non-FBS home team
    & (pd.notna(data['away_conference'])) # games with a non-FBS away team
]

# %%
data['home_spread'] = np.where(data['neutral_site'] == True, data['home_points'] - data['away_points'], (data['home_points'] - data['away_points'] - 2.5))
data['away_spread'] = -data['home_spread']
data.head()
# Out:
#            id  season  week season_type                start_date  \
# 0   401110723    2019     1     regular  2019-08-24T23:00:00.000Z
# 1   401114164    2019     1     regular  2019-08-25T02:30:00.000Z
# 4   401117854    2019     1     regular  2019-08-29T23:00:00.000Z
# 9   401111653    2019     1     regular  2019-08-30T00:00:00.000Z
# 11  401114236    2019     1     regular  2019-08-30T00:00:00.000Z
#
#     neutral_site  conference_game  attendance  venue_id  \
# 0           True            False         NaN      4013
# 1          False            False         NaN      3610
# 4          False            False         NaN      3854
# 9          False             True         NaN      3836
# 11         False            False         NaN      4729
#
#                              venue  ... home_points  home_line_scores  \
# 0            Camping World Stadium  ...        24.0     [7, 0, 10, 7]
# 1                    Aloha Stadium  ...        45.0   [14, 14, 7, 10]
# 4                  Nippert Stadium  ...        24.0      [7, 3, 7, 7]
# 9                 Memorial Stadium  ...        52.0  [14, 14, 14, 10]
# 11  Benson Field at Yulman Stadium  ...        42.0    [7, 21, 14, 0]
#
#     home_post_win_prob              away_team  away_conference away_points  \
# 0             0.905953                  Miami              ACC        20.0
# 1             0.688630                Arizona           Pac-12        38.0
# 4             0.996829                   UCLA           Pac-12        14.0
# 9             0.999976           Georgia Tech              ACC        14.0
# 11            0.999668  Florida International   Conference USA        14.0
#
#    away_line_scores  away_post_win_prob home_spread  away_spread
# 0     [3, 10, 0, 7]            0.094047         4.0         -4.0
# 1    [0, 21, 14, 3]            0.311370         4.5         -4.5
# 4      [0, 7, 7, 0]            0.003171         7.5         -7.5
# 9      [0, 0, 7, 7]            0.000024        35.5        -35.5
# 11     [0, 7, 7, 0]            0.000332        25.5        -25.5
#
# [5 rows x 22 columns]

# %%
teams = pd.concat([
    data[['home_team', 'home_spread', 'away_team']].rename(columns={'home_team': 'team', 'home_spread': 'spread', 'away_team': 'opponent'}),
    data[['away_team', 'away_spread', 'home_team']].rename(columns={'away_team': 'team', 'away_spread': 'spread', 'home_team': 'opponent'})
])

teams.head()
# Out:
#           team  spread               opponent
# 0      Florida     4.0                  Miami
# 1      Hawai'i     4.5                Arizona
# 4   Cincinnati     7.5                   UCLA
# 9      Clemson    35.5           Georgia Tech
# 11      Tulane    25.5  Florida International

# %%
teams['spread'] = np.where(teams['spread'] > 28, 28, teams['spread']) # cap the upper bound scoring margin at +28 points
teams['spread'] = np.where(teams['spread'] < -28, -28, teams['spread']) # cap the lower bound scoring margin at -28 points
teams.head()
# Out:
#           team  spread               opponent
# 0      Florida     4.0                  Miami
# 1      Hawai'i     4.5                Arizona
# 4   Cincinnati     7.5                   UCLA
# 9      Clemson    28.0           Georgia Tech
# 11      Tulane    25.5  Florida International

# %%
spreads = teams.groupby('team').spread.mean()
spreads.head()
# Out:
# team
# Air Force            11.833333
# Akron               -21.125000
# Alabama              20.333333
# Appalachian State    15.307692
# Arizona             -11.363636
# Name: spread, dtype: float64

# %%
# create empty arrays
terms = []
solutions = []

for team in spreads.keys():
    row = []
    # get a list of team opponents
    opps = list(teams[teams['team'] == team]['opponent'])
    
    for opp in spreads.keys():
        if opp == team:
        	# coefficient for the team should be 1
            row.append(1)
        elif opp in opps:
        	# coefficient for opponents should be 1 over the number of opponents
            row.append(-1.0/len(opps))
        else:
        	# teams not faced get a coefficient of 0
            row.append(0)
            
    terms.append(row)
    
    # average game spread on the other side of the equation
    solutions.append(spreads[team])

# %%
solutions = np.linalg.solve(np.array(terms), np.array(solutions))
solutions
# Out:
# array([  1.79672725, -39.08903295,  17.06772981,   2.63123524,
#        -14.07716457,  -2.92386189, -14.8812829 , -12.42198894,
#        -13.92959886,  10.96520255,  -9.21575756, -12.97182226,
#          4.57983771,   0.44876888, -10.2441261 , -31.35805973,
#         -8.49057353,  -4.41974184, -13.35039431, -17.61234723,
#          0.06836768,  16.54668574, -17.84899588, -10.48632802,
#        -17.43812369, -27.94919394,  -8.91890716, -22.57238647,
#        -16.65961574,   9.92082363,  -0.28219385, -18.90779661,
#         -7.84716911, -12.31634427,  11.18280802,  -8.4928969 ,
#        -16.84429977, -17.00179517, -10.48487627,  -8.66932718,
#         -9.16716596,  -1.91868087,   6.32490962,   3.90373189,
#        -12.77354041,   0.82170458, -14.03974808,  -2.8757901 ,
#         21.25461242, -14.25571255,  -0.5456657 , -15.45137415,
#        -10.4325315 ,  -7.42208726, -12.01403714, -12.61358895,
#          5.13528189,  -6.69151336, -14.89635134,   8.01635092,
#         -3.24032423, -15.01725176,   5.31139764,  -4.12867054,
#         -4.39101833, -18.55249613,   3.85825273,  -6.14650031,
#        -19.39727574, -24.53415144, -26.16001573,  -1.23749635,
#        -19.50659499, -21.46449269, -11.93615601,   9.06434196,
#        -12.6938653 ,  20.08265333,   9.61786705,   1.5411069 ,
#        -26.53562233,  -3.44244726,  10.30657433,  -5.44981897,
#         10.50456251,  -8.28516659,  -9.44022591, -20.71406979,
#        -22.32728316,  -0.4435908 ,  -6.3237006 , -15.31083524,
#        -23.83258438,  -6.90606199, -14.86975228, -12.62806948,
#        -10.86818454, -13.21315945,  -0.17276497,  -9.3782689 ,
#         -5.00264238,   5.9930517 ,   2.64468928, -25.30176402,
#         -6.56428424, -22.05804869, -16.25137101,  -4.11405577,
#         -8.47111764, -14.46908446,   4.04955695,  -9.24578369,
#        -42.7276733 , -23.82633604,   1.03645804, -27.66164742,
#        -35.00488338,   8.48407555, -12.18320657, -20.95370642,
#         -1.60566132,  -3.20997859,  -6.97802792,   6.34721941,
#         -2.60737211, -10.13607311,  -7.53946081, -12.27415786,
#          8.88225848,  -5.45545814])

# %%
ratings = list(zip( spreads.keys(), solutions ))
srs = pd.DataFrame(ratings, columns=['team', 'rating'])
srs.head()
# Out:
#                 team     rating
# 0          Air Force   1.796727
# 1              Akron -39.089033
# 2            Alabama  17.067730
# 3  Appalachian State   2.631235
# 4            Arizona -14.077165

# %%
rankings = srs.sort_values('rating', ascending=False).reset_index()[['team', 'rating']]
rankings.loc[:24]
# Out:
#                  team     rating
# 0                 LSU  21.254612
# 1          Ohio State  20.082653
# 2             Alabama  17.067730
# 3             Clemson  16.546686
# 4             Georgia  11.182808
# 5              Auburn  10.965203
# 6          Penn State  10.504563
# 7              Oregon  10.306574
# 8             Florida   9.920824
# 9            Oklahoma   9.617867
# 10         Notre Dame   9.064342
# 11          Wisconsin   8.882258
# 12               Utah   8.484076
# 13           Michigan   8.016351
# 14         Washington   6.347219
# 15               Iowa   6.324910
# 16              Texas   5.993052
# 17          Minnesota   5.311398
# 18            Memphis   5.135282
# 19             Baylor   4.579838
# 20                UCF   4.049557
# 21         Iowa State   3.903732
# 22               Navy   3.858253
# 23          Texas A&M   2.644689
# 24  Appalachian State   2.631235

# %% [markdown]
# Go back and tinker.
#
# What happens to our ratings if we do any of the following?
# * Adjust home field advantage up or down from 2.5
# * Remove home field advantage adjustment completely
# * Adjust the scoring margin cap up or down from 28
# * Remove the scoring margin cap completely
